# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

url = r'C:\Users\Eduardo Fonteneli\Desktop\Biblioteca\PROGRAMAÇÃO\Cientista de Dados - EBAC\Módulo 6/b1abb33c4f.csv'
df = pd.read_csv(url)

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
df[['IDADEMAE']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
df_peso=pd.DataFrame(df['PESO']/1000)
df_peso[['PESO']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.displot(data = df2
            ,alpha = .25
            ,x = 'IDADEMAE'
            ,bins = 20
            
            ,kde = True
           )

# %%
df2=pd.DataFrame(df['IDADEMAE'])

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.displot(data = df_peso
            ,alpha = .25
            ,x = 'PESO'
            ,bins = 20
            ,element = 'step'
            ,kde = True
           )
